# %%
import whisper
model = whisper.load_model("medium")
text = model.transcribe(r"C:\Users\LA CURACAO CHIMBOTE\Downloads\Birthday-Girl--I-Love-Your-Tears--The-Caraway--bluevery-label.mp3")["text"]
print(text)

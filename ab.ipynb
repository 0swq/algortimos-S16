# %%
#Crear nodo
class Nodo:
    def __init__(self,valor):
        self.izquierda=None
        self.derecha=None
        self.valor=None

# %%
raiz = Nodo(10)

print(f"Nodo creado con valor: {raiz.valor}")
print(f"Nodo creado con valor: {raiz.valor}")
print(f"Nodo creado con valor: {raiz.valor}")

# %%
#Desafio 1
raiz = Nodo(50)

print(f"Valor: {raiz.valor}")
